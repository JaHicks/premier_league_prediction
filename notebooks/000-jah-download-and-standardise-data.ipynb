# %% [markdown]
# Manually work through the downloading and standardising steps.
# This is not needed when you run: make data

# %%
# auto load changes to Python files
# %load_ext autoreload
# %autoreload 2

# %%
from src.data import make_dataset
import pandas as pd

# %%
make_dataset.download_match_data("../data/raw")

# %%
make_dataset.standardise_data_format("../data/raw", "../data/interim")

# %%
matches = pd.read_csv("../data/interim/matches_raw.csv")

# Show random sample of records for quick check
matches.sample(10)
# Out:
#              date     home_team   away_team  home_goals  away_goals result  \
# 7839   2008-11-30    Portsmouth   Blackburn         3.0         2.0      H
# 11283  2012-09-18    Birmingham      Bolton         2.0         1.0      H
# 18197  2019-12-29           QPR        Hull         1.0         2.0      A
# 6857   2007-11-24   Southampton   Blackpool         1.0         0.0      H
# 6381   2007-04-06          Hull     Norwich         1.0         2.0      A
# 7721   2008-10-29         Stoke  Sunderland         1.0         0.0      H
# 7107   2008-01-30      West Ham   Liverpool         1.0         0.0      H
# 6547   2007-08-15    Portsmouth  Man United         1.0         1.0      D
# 8951   2010-02-06  Bristol City    Coventry         1.0         1.0      D
# 4824   2005-09-24         Leeds     Ipswich         0.0         2.0      A
#
#        home_shots  away_shots  home_shotsOnTarget  away_shotsOnTarget  ...  \
# ...
